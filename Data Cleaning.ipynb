# %%
import pandas as pd
import os
import chardet
import re

# %%
# how is it encoded
file = 'data_640_validated.csv'

with open(file, "rb") as f:
    file_encoding = chardet.detect(f.read(10))
    encoding = file_encoding['encoding']
    print(f"file encodoing:{encoding}")
df = pd.read_csv(file, encoding=encoding)
df.head()
# Out:
# file encodoing:ISO-8859-1
#    Unnamed: 0           ï..O1               A1_1       A1_2      A2  \
# 0         598  5/29/2020 8:11          Filipino        Asia    Male
# 1         230  5/23/2020 1:54           American  US/Canada    Male
# 2         232  5/23/2020 2:01           American  US/Canada    Male
# 3         308  5/25/2020 1:34           Filipino       Asia  Female
# 4         231  5/23/2020 2:00  Mexican American   US/Canada    Male
#
#                  A3     A4  A5                  A6                     A7  \
# 0  Secondary school  A pet  11               Asian  Single, never married
# 1  Secondary school   Both  13               White  Single, never married
# 2  Secondary school   Both  13               White  Single, never married
# 3       High school  A pet  13               Asian  Single, never married
# 4  Secondary school  A pet  14  Hispanic or Latino  Single, never married
#
#    ... F23 F24 F25 F26  F27  F28  F29  F30  F31  F32
# 0  ...   1   2   5   4    5    4    1    5    1    1
# 1  ...   1   1   4   2    5    4    2    4    1    4
# 2  ...   1   1   4   1    5    3    2    5    2    4
# 3  ...   3   2   3   4    5    5    2    5    1    2
# 4  ...   5   4   4   3    4    4    1    5    5    5
#
# [5 rows x 96 columns]

# %%
# Determine file size & number of rows
file_size_KB = os.path.getsize(file)/1024
file_size_MB= os.path.getsize(file)/(1024 * 1024)
num_rows, num_columns = df.shape

print(f"file_size:{round(file_size_KB, 2)}KB")
print(f"file_size:{round(file_size_MB, 2)}MB")
print(f"file_rows:{num_rows}")
print(f"file_columns:{num_columns}")
# Out:
# file_size:272.51KB
# file_size:0.27MB
# file_rows:640
# file_columns:96

# %%
# chang column name
df = df.drop(columns="Unnamed: 0")
df.rename(columns = {"ï..O1":"Date", "A1_1":"nationality","A1_2": "Continent","A2": "Gender", "A3": "education", "A4": "Pet",
                     "A5":"Age", "A6": "Ethnicity", "A7":"Martial", "A8":"job"}, inplace = True)
df.head()
# Out:
#              Date        nationality  Continent  Gender         education  \
# 0  5/29/2020 8:11          Filipino        Asia    Male  Secondary school
# 1  5/23/2020 1:54           American  US/Canada    Male  Secondary school
# 2  5/23/2020 2:01           American  US/Canada    Male  Secondary school
# 3  5/25/2020 1:34           Filipino       Asia  Female       High school
# 4  5/23/2020 2:00  Mexican American   US/Canada    Male  Secondary school
#
#      Pet Age           Ethnicity                Martial        job  ... F23  \
# 0  A pet  11               Asian  Single, never married  A student  ...   1
# 1   Both  13               White  Single, never married  A student  ...   1
# 2   Both  13               White  Single, never married  A student  ...   1
# 3  A pet  13               Asian  Single, never married  A student  ...   3
# 4  A pet  14  Hispanic or Latino  Single, never married  A student  ...   5
#
#   F24 F25  F26  F27  F28  F29  F30  F31  F32
# 0   2   5    4    5    4    1    5    1    1
# 1   1   4    2    5    4    2    4    1    4
# 2   1   4    1    5    3    2    5    2    4
# 3   2   3    4    5    5    2    5    1    2
# 4   4   4    3    4    4    1    5    5    5
#
# [5 rows x 95 columns]

# %%
# Check data formats
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 95 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         640 non-null    object
#  1   nationality  640 non-null    object
#  2   Continent    640 non-null    object
#  3   Gender       640 non-null    object
#  4   education    640 non-null    object
#  5   Pet          554 non-null    object
#  6   Age          640 non-null    object
#  7   Ethnicity    640 non-null    object
#  8   Martial      640 non-null    object
#  9   job          640 non-null    object
#  10  B1           640 non-null    object
#  11  B2           640 non-null    object
#  12  B3           640 non-null    object
#  13  C1           640 non-null    int64
#  14  C2           640 non-null    int64
#  15  C3           640 non-null    int64
#  16  C4           640 non-null    int64
#  17  C5           640 non-null    int64
#  18  C6           640 non-null    int64
#  19  C7           640 non-null    int64
#  20  C8           640 non-null    int64
#  21  C9           640 non-null    int64
#  22  C10          640 non-null    int64
#  23  C11          640 non-null    int64
#  24  C12          640 non-null    int64
#  25  C13          640 non-null    int64
#  26  C14          640 non-null    int64
#  27  C15          640 non-null    int64
#  28  D1           634 non-null    object
#  29  D2           635 non-null    object
#  30  D3           639 non-null    object
#  31  D4           639 non-null    object
#  32  D5           640 non-null    object
#  33  D6           640 non-null    object
#  34  D7           627 non-null    object
#  35  E1           640 non-null    int64
#  36  E2           640 non-null    int64
#  37  E3           640 non-null    int64
#  38  E4           640 non-null    int64
#  39  E5           640 non-null    int64
#  40  E6           640 non-null    int64
#  41  E7           640 non-null    int64
#  42  E8           640 non-null    int64
#  43  E9           640 non-null    int64
#  44  E10          640 non-null    int64
#  45  E11          640 non-null    int64
#  46  E12          640 non-null    int64
#  47  E13          640 non-null    int64
#  48  E14          640 non-null    int64
#  49  E15          640 non-null    int64
#  50  E16          640 non-null    int64
#  51  E17          640 non-null    int64
#  52  E18          640 non-null    int64
#  53  E19          640 non-null    int64
#  54  E20          640 non-null    int64
#  55  E21          640 non-null    int64
#  56  E22          640 non-null    int64
#  57  E23          640 non-null    int64
#  58  E24          640 non-null    int64
#  59  E25          640 non-null    int64
#  60  E26          640 non-null    int64
#  61  E27          640 non-null    int64
#  62  E28          640 non-null    int64
#  63  F1           640 non-null    int64
#  64  F2           640 non-null    int64
#  65  F3           640 non-null    int64
#  66  F4           640 non-null    int64
#  67  F5           640 non-null    int64
#  68  F6           640 non-null    int64
#  69  F7           640 non-null    int64
#  70  F8           640 non-null    int64
#  71  F9           640 non-null    int64
#  72  F10          640 non-null    int64
#  73  F11          640 non-null    int64
#  74  F12          640 non-null    int64
#  75  F13          640 non-null    int64
#  76  F14          640 non-null    int64
#  77  F15          640 non-null    int64
#  78  F16          640 non-null    int64
#  79  F17          640 non-null    int64
#  80  F18          640 non-null    int64
#  81  F19          640 non-null    int64
#  82  F20          640 non-null    int64
#  83  F21          640 non-null    int64
#  84  F22          640 non-null    int64
#  85  F23          640 non-null    int64
#  86  F24          640 non-null    int64
#  87  F25          640 non-null    int64
#  88  F26          640 non-null    int64
#  89  F27          640 non-null    int64
#  90  F28          640 non-null    int64
#  91  F29          640 non-null    int64
#  92  F30          640 non-null    int64
#  93  F31          640 non-null    int64
#  94  F32          640 non-null    int64
# dtypes: int64(75), object(20)
# memory usage: 475.1+ KB

# %%
# check the date
try:
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
except ValueError as e :
    print("ValueError:", e)
nan_values = df[pd.isna(df['Date'])]
if nan_values.empty:
    print("date is valid")
df.info()
# Out:
# date is valid
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 95 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         640 non-null    datetime64[ns]
#  1   nationality  640 non-null    object
#  2   Continent    640 non-null    object
#  3   Gender       640 non-null    object
#  4   education    640 non-null    object
#  5   Pet          554 non-null    object
#  6   Age          640 non-null    object
#  7   Ethnicity    640 non-null    object
#  8   Martial      640 non-null    object
#  9   job          640 non-null    object
#  10  B1           640 non-null    object
#  11  B2           640 non-null    object
#  12  B3           640 non-null    object
#  13  C1           640 non-null    int64
#  14  C2           640 non-null    int64
#  15  C3           640 non-null    int64
#  16  C4           640 non-null    int64
#  17  C5           640 non-null    int64
#  18  C6           640 non-null    int64
#  19  C7           640 non-null    int64
#  20  C8           640 non-null    int64
#  21  C9           640 non-null    int64
#  22  C10          640 non-null    int64
#  23  C11          640 non-null    int64
#  24  C12          640 non-null    int64
#  25  C13          640 non-null    int64
#  26  C14          640 non-null    int64
#  27  C15          640 non-null    int64
#  28  D1           634 non-null    object
#  29  D2           635 non-null    object
#  30  D3           639 non-null    object
#  31  D4           639 non-null    object
#  32  D5           640 non-null    object
#  33  D6           640 non-null    object
#  34  D7           627 non-null    object
#  35  E1           640 non-null    int64
#  36  E2           640 non-null    int64
#  37  E3           640 non-null    int64
#  38  E4           640 non-null    int64
#  39  E5           640 non-null    int64
#  40  E6           640 non-null    int64
#  41  E7           640 non-null    int64
#  42  E8           640 non-null    int64
#  43  E9           640 non-null    int64
#  44  E10          640 non-null    int64
#  45  E11          640 non-null    int64
#  46  E12          640 non-null    int64
#  47  E13          640 non-null    int64
#  48  E14          640 non-null    int64
#  49  E15          640 non-null    int64
#  50  E16          640 non-null    int64
#  51  E17          640 non-null    int64
#  52  E18          640 non-null    int64
#  53  E19          640 non-null    int64
#  54  E20          640 non-null    int64
#  55  E21          640 non-null    int64
#  56  E22          640 non-null    int64
#  57  E23          640 non-null    int64
#  58  E24          640 non-null    int64
#  59  E25          640 non-null    int64
#  60  E26          640 non-null    int64
#  61  E27          640 non-null    int64
#  62  E28          640 non-null    int64
#  63  F1           640 non-null    int64
#  64  F2           640 non-null    int64
#  65  F3           640 non-null    int64
#  66  F4           640 non-null    int64
#  67  F5           640 non-null    int64
#  68  F6           640 non-null    int64
#  69  F7           640 non-null    int64
#  70  F8           640 non-null    int64
#  71  F9           640 non-null    int64
#  72  F10          640 non-null    int64
#  73  F11          640 non-null    int64
#  74  F12          640 non-null    int64
#  75  F13          640 non-null    int64
#  76  F14          640 non-null    int64
#  77  F15          640 non-null    int64
#  78  F16          640 non-null    int64
#  79  F17          640 non-null    int64
#  80  F18          640 non-null    int64
#  81  F19          640 non-null    int64
#  82  F20          640 non-null    int64
#  83  F21          640 non-null    int64
#  84  F22          640 non-null    int64
#  85  F23          640 non-null    int64
#  86  F24          640 non-null    int64
#  87  F25          640 non-null    int64
#  88  F26          640 non-null    int64
#  89  F27          640 non-null    int64
#  90  F28          640 non-null    int64
#  91  F29          640 non-null    int64
#  92  F30          640 non-null    int64
#  93  F31          640 non-null    int64
#  94  F32          640 non-null    int64
# dtypes: datetime64[ns](1), int64(75), object(19)
# memory usage: 475.1+ KB

# %%
# check the nationality 
# range
nationality_category_counts = df['nationality'].value_counts()
print(dict(nationality_category_counts))
print("nationality_category_counts:")
print(nationality_category_counts)
# Out:
# {'American': 109, 'Filipino': 95, 'usa': 44, 'USA': 38, 'British': 33, 'United States': 28, 'Vietnam': 27, 'Vietnamese': 23, 'American ': 23, 'America': 23, 'US': 15, 'British ': 12, 'us': 12, 'Canadian': 9, 'Scottish': 8, 'uk': 8, 'U.S.': 5, 'Chinese': 4, 'Australian': 4, 'Filipino ': 4, 'Viet Nam': 3, 'Myanmar': 3, 'United States of America': 3, 'filipino': 3, 'Caucasian ': 3, 'Singaporean': 3, 'Viet nam': 2, 'English ': 2, 'Dutch': 2, 'UK': 2, 'North American': 2, 'Filipino American': 2, 'Hispanic ': 2, 'Usa': 2, 'American (USA)': 2, ' United States': 2, 'Filipino-American': 2, 'Canadian ': 2, 'White': 2, 'american': 2, 'Latina': 1, 'Hong Kong': 1, 'Mexican American ': 1, 'American (USA) ': 1, 'Colombian': 1, 'Ashenkazi Jewish': 1, 'Welsh': 1, 'Mixed race ': 1, 'New Zealand European': 1, 'American (US)': 1, 'TAIWAN': 1, 'Korean/ American': 1, 'Singapore': 1, 'the United States': 1, 'Icelandic': 1, 'Philippines': 1, 'United States ': 1, 'English, Irish, German': 1, 'Mixed nationalities': 1, 'White American ': 1, 'United States of American': 1, 'Irish': 1, 'Myanmar ': 1, '29': 1, 'US citizen': 1, 'the United States ': 1, 'FILIPINO': 1, 'USA ': 1, 'Candadian': 1, 'Argentina': 1, 'African American': 1, 'Autsralian': 1, 'Japanese': 1, 'British/English ': 1, ' American': 1, 'White British ': 1, 'Cornish': 1, 'Anerican': 1, 'Italian': 1, 'South Korean': 1, 'British - White ': 1, 'White English ': 1, 'Welsh, British': 1, 'White British': 1, 'Polish-American': 1, 'Vietnamese-American': 1, 'British / Filipino, I am a dual citizen ': 1, 'Mixed': 1, 'white': 1, 'Citizen of the United States': 1, 'China': 1, 'German': 1, ' America': 1, 'Asian': 1, 'Friendly': 1, 'Portuguese-Canadian': 1, 'canadian': 1, 'Indonesia ': 1, 'Catalan (spanish)': 1, 'French': 1, 'US Citizen': 1, 'American (U.S.A.)': 1, 'American (United States)': 1, 'Norwegian': 1, 'American (United States of America) ': 1, 'indonesian': 1, 'New Zealander': 1, 'Vieynam': 1, 'German, Native American ': 1, 'Filipino American ': 1}
# nationality_category_counts:
# nationality
# American                    109
# Filipino                     95
# usa                          44
# USA                          38
# British                      33
#                            ...
# indonesian                    1
# New Zealander                 1
# Vieynam                       1
# German, Native American       1
# Filipino American             1
# Name: count, Length: 110, dtype: int64

# %%
# build the map
country_mapping = {
    'American': 'USA',
    'Filipino': 'Philippines',
    'usa': 'USA',
    'USA': 'USA',
    'British': 'UK',
    'United States': 'USA',
    'Vietnam': 'Vietnam',
    'Vietnamese': 'Vietnam',
    'American ': 'USA',
    'America': 'USA',
    'US': 'USA',
    'British ': 'UK',
    'us': 'USA',
    'Canadian': 'Canada',
    'Scottish': 'UK',
    'uk': 'UK',
    'U.S.': 'USA',
    'Chinese': 'China',
    'Australian': 'Australia',
    'Filipino ': 'Philippines',
    'Viet Nam': 'Vietnam',
    'Myanmar': 'Myanmar',
    'United States of America': 'USA',
    'filipino': 'Philippines',
    'Caucasian ': 'Unspecified',
    'Singaporean': 'Singapore',
    'Viet nam': 'Vietnam',
    'English ': 'UK',
    'Dutch': 'Netherlands',
    'UK': 'UK',
    'North American': 'USA',
    'Filipino American': 'USA',
    'Hispanic ': 'Spain',
    'Usa': 'USA',
    'American (USA)': 'USA',
    ' United States': 'USA',
    'Filipino-American': 'USA',
    'Canadian ': 'Canada',
    'White': 'Unspecified',
    'american': 'USA',
    'Latina': 'Unspecified',
    'Hong Kong': 'Hong Kong',
    'Mexican American ': 'USA',
    'American (USA) ': 'USA',
    'Colombian': 'Colombia',
    'Ashenkazi Jewish': 'Unspecified',
    'Welsh': 'UK',
    'Mixed race ': 'mix',
    'New Zealand European': 'New Zealand',
    'American (US)': 'USA',
    'TAIWAN': 'Taiwan',
    'Korean/ American': 'mix',
    'Singapore': 'Singapore',
    'the United States': 'USA',
    'Icelandic': 'Iceland',
    'Philippines': 'Philippines',
    'United States ': 'USA',
    'English, Irish, German': 'mix',
    'Mixed nationalities': 'mix',
    'White American ': 'USA',
    'United States of American': 'USA',
    'Irish': 'Ireland',
    'Myanmar ': 'Myanmar',
    '29': 'Unspecified',
    'US citizen': 'USA',
    'the United States ': 'USA',
    'FILIPINO': 'Philippines',
    'USA ': 'USA',
    'Candadian': 'Canada',
    'Argentina': 'Argentina',
    'African American': 'USA',
    'Autsralian': 'Australia',
    'Japanese': 'Japan',
    'British/English ': 'UK',
    ' American': 'USA',
    'White British ': 'UK',
    'Cornish': 'UK',
    'Anerican': 'USA',
    'Italian': 'Italy',
    'South Korean': 'South Korea',
    'British - White ': 'UK',
    'White English ': 'UK',
    'Welsh, British': 'UK',
    'White British': 'UK',
    'Polish-American': 'mix',
    'Vietnamese-American': 'mix',
    'British / Filipino, I am a dual citizen ': 'mix',
    'Mixed': 'mix',
    'white': 'Unspecified',
    'Citizen of the United States': 'USA',
    'China': 'China',
    'German': 'Germany',
    ' America': 'USA',
    'Asian': 'Unspecified',
    'Friendly': 'Unspecified',
    'Portuguese-Canadian': 'mix',
    'canadian': 'Canada',
    'Indonesia ': 'Indonesia',
    'Catalan (spanish)': 'Spain',
    'French': 'France',
    'US Citizen': 'USA',
    'American (U.S.A.)': 'USA',
    'American (United States)': 'USA',
    'Norwegian': 'Norway',
    'American (United States of America) ': 'USA',
    'indonesian': 'Indonesia',
    'New Zealander': 'New Zealand',
    'Vieynam': 'Vietnam',
    'German, Native American ': 'mix',
    'Filipino American ': 'USA'
}

# %%
# mapping
df['nationality'] = df['nationality'].map(country_mapping)
nationality_category_counts = df['nationality'].value_counts()
print(dict(nationality_category_counts))
print("nationality_category_counts:")
print(nationality_category_counts)
# Out:
# {'USA': 334, 'Philippines': 104, 'UK': 73, 'Vietnam': 56, 'Canada': 13, 'Unspecified': 11, 'mix': 10, 'Australia': 5, 'China': 5, 'Singapore': 4, 'Myanmar': 4, 'Spain': 3, 'New Zealand': 2, 'Netherlands': 2, 'Indonesia': 2, 'Argentina': 1, 'Hong Kong': 1, 'Ireland': 1, 'Colombia': 1, 'Taiwan': 1, 'Italy': 1, 'Japan': 1, 'France': 1, 'South Korea': 1, 'Germany': 1, 'Norway': 1, 'Iceland': 1}
# nationality_category_counts:
# nationality
# USA            334
# Philippines    104
# UK              73
# Vietnam         56
# Canada          13
# Unspecified     11
# mix             10
# Australia        5
# China            5
# Singapore        4
# Myanmar          4
# Spain            3
# New Zealand      2
# Netherlands      2
# Indonesia        2
# Argentina        1
# Hong Kong        1
# Ireland          1
# Colombia         1
# Taiwan           1
# Italy            1
# Japan            1
# France           1
# South Korea      1
# Germany          1
# Norway           1
# Iceland          1
# Name: count, dtype: int64

# %%
# check the continent
continent_category_counts = df['Continent'].value_counts()
print(dict(continent_category_counts))
print("continent_category_counts:")
print(continent_category_counts)
# Out:
# {'US/Canada': 352, 'Asia': 180, 'EU': 92, 'Other': 16}
# continent_category_counts:
# Continent
# US/Canada    352
# Asia         180
# EU            92
# Other         16
# Name: count, dtype: int64

# %%
# check the gender
Gender_category_counts = df['Gender'].value_counts()
print(dict(Gender_category_counts))
print("Gender_category_counts:")
print(Gender_category_counts)
# Out:
# {'Female': 412, 'Male': 228}
# Gender_category_counts:
# Gender
# Female    412
# Male      228
# Name: count, dtype: int64

# %%
# check the education
education_category_counts = df['education'].value_counts()
print(dict(education_category_counts))
print("education_category_counts:")
print(education_category_counts)
# Out:
# {'Undergraduate school': 336, 'Graduate school and higher': 162, 'High school': 128, 'Secondary school': 13, 'Primary school': 1}
# education_category_counts:
# education
# Undergraduate school          336
# Graduate school and higher    162
# High school                   128
# Secondary school               13
# Primary school                  1
# Name: count, dtype: int64

# %%
# check the Pet
pet_category_counts = df['Pet'].value_counts()
print(dict(pet_category_counts))
print("pet_category_counts:")
print(pet_category_counts)
# Out:
# {'Both': 272, 'A pet': 215, 'A garden': 67}
# pet_category_counts:
# Pet
# Both        272
# A pet       215
# A garden     67
# Name: count, dtype: int64

# %%
# change the 'None' to 'Neither'
df = df.fillna("Neither")
pet_category_counts = df['Pet'].value_counts()
print(dict(pet_category_counts))
print("pet_category_counts:")
print(pet_category_counts)
# Out:
# {'Both': 272, 'A pet': 215, 'Neither': 86, 'A garden': 67}
# pet_category_counts:
# Pet
# Both        272
# A pet       215
# Neither      86
# A garden     67
# Name: count, dtype: int64

# %%
# check the age
# Check if the "Age" column contains non-numeric data
numeric_column = pd.to_numeric(df['Age'], errors='coerce')
non_numeric_values = df[~numeric_column.notna()]
print(non_numeric_values)
# Out:
#                    Date nationality  Continent  Gender             education  \
# 638 2020-05-26 03:05:00         USA  US/Canada  Female  Undergraduate school
# 639 2020-06-15 18:51:00     Vietnam       Asia  Female  Undergraduate school
#
#          Pet     Age Ethnicity                          Martial  \
# 638     Both     30s     Other  Married or domestic partnership
# 639  Neither  sub 28     Asian            Single, never married
#
#                     job  ... F23 F24 F25  F26  F27  F28  F29  F30  F31  F32
# 638       Self-employed  ...   3   3   4    3    3    3    3    2    2    3
# 639  Employed for wages  ...   1   1   2    3    3    2    1    2    1    1
#
# [2 rows x 95 columns]

# %%
df.at[638, 'Age'] = 30
df.at[639, 'Age'] = 28

# %%
#Ethnicity
ethnicity_category_counts = df['Ethnicity'].value_counts()
print(dict(ethnicity_category_counts))
print("ethnicity_category_counts:")
print(ethnicity_category_counts)
# Out:
# {'White': 347, 'Asian': 200, 'Hispanic or Latino': 40, 'Black or African American': 29, 'Other': 9, 'Pacific Islander': 8, 'Native American or American Indian': 7}
# ethnicity_category_counts:
# Ethnicity
# White                                 347
# Asian                                 200
# Hispanic or Latino                     40
# Black or African American              29
# Other                                   9
# Pacific Islander                        8
# Native American or American Indian      7
# Name: count, dtype: int64

# %%
# check the Martial
martial_category_counts = df['Martial'].value_counts()
print(dict(martial_category_counts))
print("martial_category_counts:")
print(martial_category_counts)
# Out:
# {'Single, never married': 391, 'Married or domestic partnership': 237, 'Divorced': 6, 'Separated': 3, 'Widowed': 3}
# martial_category_counts:
# Martial
# Single, never married              391
# Married or domestic partnership    237
# Divorced                             6
# Separated                            3
# Widowed                              3
# Name: count, dtype: int64

# %%
# check the Job
job_category_counts = df['job'].value_counts()
print(dict(job_category_counts))
print("job_category_counts:")
print(job_category_counts)
# Out:
# {'Employed for wages': 357, 'A student': 123, 'Out of work and looking for work': 55, 'Self-employed': 44, 'Out of work but not currently looking for work': 27, 'Unable to work': 17, 'A homemaker': 14, 'Military': 2, 'Retired': 1}
# job_category_counts:
# job
# Employed for wages                                357
# A student                                         123
# Out of work and looking for work                   55
# Self-employed                                      44
# Out of work but not currently looking for work     27
# Unable to work                                     17
# A homemaker                                        14
# Military                                            2
# Retired                                             1
# Name: count, dtype: int64

# %%
df.rename(columns = {"B1": "isolated", "B2": "Time", "B3": "Covid-19"}, inplace = True)

# %%
# check the isolated
isolated_category_counts = df['isolated'].value_counts()
print(dict(isolated_category_counts))
print("isolated_category_counts:")
print(isolated_category_counts)
# Out:
# {'Yes': 499, 'No': 141}
# isolated_category_counts:
# isolated
# Yes    499
# No     141
# Name: count, dtype: int64

# %%
# check the time
time_category_counts = df['Time'].value_counts()
print(dict(time_category_counts))
print("time_category_counts:")
print(time_category_counts)
# Out:
# {'More than a month': 403, 'No self-isolation/social distancing': 111, 'More than 3 weeks': 45, 'More than 2 weeks': 42, 'More than a week': 20, '7 days': 7, '1 day': 4, '4 days': 3, '5 days': 2, '6 days': 2, '3 days': 1}
# time_category_counts:
# Time
# More than a month                      403
# No self-isolation/social distancing    111
# More than 3 weeks                       45
# More than 2 weeks                       42
# More than a week                        20
# 7 days                                   7
# 1 day                                    4
# 4 days                                   3
# 5 days                                   2
# 6 days                                   2
# 3 days                                   1
# Name: count, dtype: int64

# %%
# check the Covid-19
covid_category_counts = df['Covid-19'].value_counts()
print(dict(covid_category_counts))
print("covid_category_counts:")
print(covid_category_counts)
# Out:
# {'Worried': 319, 'Very worried': 154, 'A little': 148, 'Not at all': 19}
# covid_category_counts:
# Covid-19
# Worried         319
# Very worried    154
# A little        148
# Not at all       19
# Name: count, dtype: int64

# %%
# check the D1:How long have you been playing video games?
d1_category_counts = df['D1'].value_counts()
print(dict(d1_category_counts))
print("d1_category_counts:")
print(d1_category_counts)
# Out:
# {'More than 3 years': 507, '2-3 years': 55, '1-2 years': 46, '0-1 years': 26, 'Neither': 6}
# d1_category_counts:
# D1
# More than 3 years    507
# 2-3 years             55
# 1-2 years             46
# 0-1 years             26
# Neither                6
# Name: count, dtype: int64

# %%
# check the D2:Which genre of video games do you often play?
d2_category_counts = df['D2'].value_counts()
print(dict(d2_category_counts))
print("d2_category_counts:")
print(d2_category_counts)
# Out:
# {'Action, Adventure, RPG, Simulation, Strategy, Sports': 67, 'Action, Adventure, RPG, Simulation, Strategy': 52, 'Adventure, RPG, Simulation, Strategy': 43, 'Adventure, RPG, Simulation': 41, 'Action, Adventure, RPG, Simulation': 40, 'RPG, Simulation': 27, 'Simulation': 25, 'Action, Adventure, RPG, Strategy': 23, 'RPG': 22, 'Adventure, RPG, Strategy': 22, 'RPG, Simulation, Strategy': 18, 'Adventure': 18, 'Adventure, RPG': 18, 'Action, Adventure, RPG': 17, 'Adventure, Simulation, Strategy': 13, 'Action, Adventure, Simulation, Strategy': 13, 'Adventure, Simulation': 13, 'RPG, Strategy': 11, 'Simulation, Strategy': 10, 'Action, RPG, Simulation': 9, 'Action, Adventure': 7, 'Adventure, Strategy': 6, 'Neither': 5, 'Action': 4, 'Strategy': 4, 'RPG, Simulation, Sports': 4, 'Adventure, Simulation, Sports': 4, 'Action, RPG, Simulation, Strategy': 4, 'Action, RPG': 4, 'Action, RPG, Strategy': 4, 'Action, Adventure, Strategy': 4, 'Action, Simulation, Strategy': 3, 'RPG, Simulation, Puzzle': 3, 'Sports': 3, 'Adventure, RPG, Simulation, Strategy, Sports': 3, 'Adventure, RPG, Strategy, Sports': 2, 'Action, Adventure, RPG, Strategy, Sports': 2, 'Action, Adventure, RPG, Simulation, Sports': 2, 'Action, Adventure, Simulation, Strategy, Sports': 2, 'Adventure, RPG, Simulation, Puzzle': 2, 'Action, Adventure, Simulation, Sports': 2, 'Action, Adventure, Sports': 2, 'Action, RPG, Simulation, Sports': 2, 'Action, Adventure, Simulation': 2, 'Strategy, Sports': 2, 'RPG, Strategy, Sports': 2, 'Action, Adventure, RPG, Simulation, Strategy, Whatever looks fun': 1, 'Adventure, RPG, Simulation, Sports': 1, 'RPG, Simulation, Strategy, Puzzle': 1, 'RPG, Dancing': 1, 'Puzzle': 1, 'Action, RPG, Sports': 1, 'Action, Adventure, RPG, MOBA': 1, 'Action, Adventure, MOBA': 1, 'Action, Adventure, RPG, Simulation, MMORPG': 1, 'MOBA': 1, 'Action, Adventure, RPG, Simulation, Strategy, Visual Novel': 1, 'Adventure, Puzzle': 1, 'Action, Adventure, RPG, Simulation, Strategy, Sex Dungeon Design': 1, 'FPS': 1, 'Adventure, RPG, Simulation, Strategy, Visual Novels': 1, 'Action, RPG, Simulation, Fighting, 3D platformer': 1, 'Action, Adventure, Simulation, Strategy, puzzle': 1, 'Action, RPG, Strategy, Sports': 1, 'Adventure, Simulation, Strategy, Puzzle': 1, 'Action, RPG, Simulation, Strategy, Sports': 1, 'Action, Adventure, RPG, Simulation, Strategy, Mmo': 1, 'RPG, First person shooter': 1, 'Animal crossing and the Sims since they came out': 1, 'Adventure, Simulation, puzzle': 1, 'Action, Adventure, Strategy, Creation games ex: rec room vrchat': 1, 'Action, Adventure, RPG, Simulation, Sports, Platformers': 1, 'RPG, Simulation, Strategy, FPS': 1, 'Iâ\x80\x99m not sure what category, but League of Legends and Fortnite ': 1, 'Action, Adventure, Simulation, Puzzle ': 1, 'Action, Adventure, Strategy, Sports': 1, 'Adventure, Simulation, Visual Novels': 1, 'Adventure, Simulation, Story-driven': 1, 'RPG, Simulation, Platform': 1, 'Action, Adventure, RPG, Strategy, Platform': 1, 'Action, Adventure, Simulation, Strategy, Varied themes all in one game ex: rec room, vr chat,': 1, 'Action, Adventure, Strategy, FPS MMORPG': 1, 'Adventure, Simulation, Strategy, puzzle, trivia': 1, 'Action, Adventure, RPG, Sports': 1, 'Action, Adventure, RPG, FPS, TPS': 1, 'Action, Adventure, Simulation, FPS': 1, 'RPG, Versus fighting': 1, 'Adventure, Sports': 1, 'Action, Adventure, RPG, Simulation, Strategy, Sports, Puzzle': 1, 'Action, Adventure, RPG, Simulation, Strategy, Sports, almost all of them': 1, 'Action, Strategy': 1, 'Simulation, Sports': 1, 'Action, Simulation': 1, 'Action, Adventure, Simulation, Point and click, first person shooter': 1, 'Action, Adventure, RPG, Simulation, Strategy, Farming / Chill': 1, 'Simulation, Strategy, Sports': 1, 'Action, RPG, 2D Fighter': 1, 'Action, Adventure, RPG, Simulation, Strategy, Horror': 1, 'Action, Adventure, RPG, Simulation, Rhythm': 1, 'Action, Adventure, RPG, Simulation, Strategy, Massively Multiplayer Online Games': 1}
# d2_category_counts:
# D2
# Action, Adventure, RPG, Simulation, Strategy, Sports                                67
# Action, Adventure, RPG, Simulation, Strategy                                        52
# Adventure, RPG, Simulation, Strategy                                                43
# Adventure, RPG, Simulation                                                          41
# Action, Adventure, RPG, Simulation                                                  40
#                                                                                     ..
# Simulation, Strategy, Sports                                                         1
# Action, RPG, 2D Fighter                                                              1
# Action, Adventure, RPG, Simulation, Strategy, Horror                                 1
# Action, Adventure, RPG, Simulation, Rhythm                                           1
# Action, Adventure, RPG, Simulation, Strategy, Massively Multiplayer Online Games     1
# Name: count, Length: 100, dtype: int64

# %%
def check_encoding(row):
    result = chardet.detect(row.encode())
    if result['encoding'] != 'utf-8':
        return True
    return False

# Identify rows with invalid characters
df['Invalid Characters'] = df['D2'].apply(check_encoding)

print(df[df['Invalid Characters'] == False])

# # Drop the additional column used for checking
# df = df.drop(columns=['Invalid Characters'])
# Out:
#                    Date nationality  Continent  Gender  \
# 349 2020-05-25 06:25:00         USA  US/Canada  Female
#
#                       education    Pet Age Ethnicity  \
# 349  Graduate school and higher  A pet  26     White
#
#                              Martial          job  ... F24 F25 F26  F27  F28  \
# 349  Married or domestic partnership  A homemaker  ...   1   2   2    4    3
#
#      F29  F30  F31  F32  Invalid Characters
# 349    2    4    3    2               False
#
# [1 rows x 96 columns]

# %%
print(df.at[349, "D2"])
# Out:
# Iâm not sure what category, but League of Legends and Fortnite

# %%
df.at[349, "D2"] = 'Action, Adventure, Strategy, Sports'

# %%
# check the D3:How often do you play computer/video games?
d3_category_counts = df['D3'].value_counts()
print(dict(d3_category_counts))
print("d3_category_counts:")
print(d3_category_counts)
# Out:
# {'Everyday': 258, 'Almost everyday': 249, 'Every week': 84, 'Almost every week': 25, 'Less than every month': 14, 'Every month': 9, 'Neither': 1}
# d3_category_counts:
# D3
# Everyday                 258
# Almost everyday          249
# Every week                84
# Almost every week         25
# Less than every month     14
# Every month                9
# Neither                    1
# Name: count, dtype: int64

# %%
# check the D4:How many hours on average did you spend playing game a day in the last two weeks?
d4_category_counts = df['D4'].value_counts()
print(dict(d4_category_counts))
print("d4_category_counts:")
print(d4_category_counts)
# Out:
# {'3-4 hours': 228, '2-3 hours': 179, '1-2 hours': 105, '20': 6, '5-6 hours': 5, '6': 4, '20+': 3, '6-8 hours': 3, '10-12 hours': 3, '5+': 2, '10': 2, '10+': 2, '8-10 hours': 2, '10 hours or more': 2, '7-8 hours': 2, '5': 2, '9': 2, 'More than 5 hours': 2, '5-7 hours': 1, 'More than 4': 1, '6 hours a day ': 1, 'About 9 hours a day ': 1, '5 hours': 1, 'More than 3-4 hours per day': 1, 'More than 4 hours': 1, 'Can range between 5-12 hours ': 1, '4-5 hours': 1, '7 hrs': 1, '7': 1, 'Around 6-8hrs': 1, '4 or more depending': 1, '10 hours on average': 1, '50': 1, 'More than 6 hours': 1, 'Playing alot of video games do to the pandemic ': 1, 'I lost count': 1, 'Over 7': 1, '3 - 4 hours every day': 1, '8 hours': 1, '40': 1, 'Over 4': 1, '12-Aug': 1, '5 hours more': 1, '6-7 hours': 1, '10+ hrs': 1, '14': 1, '4-8 hours': 1, '8-Jul': 1, 'Too many': 1, 'About 6 hours': 1, '6 to 7 hours': 1, 'More than 5': 1, '5 to 6 hours more or less': 1, '5 hours or more': 1, 'more than 8hrs ': 1, '56 hrs / 2 weeks': 1, 'More than 7 hours': 1, '4 to 5 hours': 1, '6 hours': 1, '50 hours': 1, 'Over 4 hours': 1, '9-Jul': 1, '6 hours ': 1, 'Definitely more than 4 but I couldnâ\x80\x99t say an exact amount. I guess upper 20s': 1, '2-3 weekdays, 5-7 on weekends. ': 1, '45': 1, 'Neither': 1, '10+ hours': 1, '10 hours': 1, '6-9 hours': 1, '10-15 hours': 1, '12+  (I donâ\x80\x99t keep count)': 1, '50+ hours ': 1, '30': 1, '6-May': 1, '10-Jul': 1, '5-8 hours': 1, '50+': 1, 'Somewhere in the 30 hour range ': 1, '6-7 hours, more on occasion': 1, "8+ because I'm in quarantine": 1, '4+': 1, '8-May': 1, '112': 1, 'More than 4 hrs ': 1, 'More ': 1, 'At least 10 hours in the last two weeks': 1, '6-7, hours, possibly more on occasion': 1, 'Way above 20hrs': 1, 'More than 4 hours ': 1, 'Can be 5+ depending on work': 1, '8': 1, 'More than 10': 1, 'More than 3-4 Hours': 1, '4hours+': 1, '12-13 (thanks quarantine)': 1, 'If im not working, i play for an entire day': 1, '4+ hours ': 1, '20-Oct': 1, 'Iâ\x80\x99ve spent a lot more time playing video games during quarantine than I have in the past few years ': 1, '8 Hours hehe': 1, 'Very much , about 6-7 hours per day': 1, '6 hours+': 1, 'probably 10+ hours a day right now': 1}
# d4_category_counts:
# D4
# 3-4 hours                                                                                                228
# 2-3 hours                                                                                                179
# 1-2 hours                                                                                                105
# 20                                                                                                         6
# 5-6 hours                                                                                                  5
#                                                                                                         ...
# Iâve spent a lot more time playing video games during quarantine than I have in the past few years       1
# 8 Hours hehe                                                                                               1
# Very much , about 6-7 hours per day                                                                        1
# 6 hours+                                                                                                   1
# probably 10+ hours a day right now                                                                         1
# Name: count, Length: 104, dtype: int64

# %%
# Function to convert time data to hours
def convert_to_hours(time_str):
    # Use regular expression to extract lower and upper limits of time range
    match = re.search(r'(\d+)(?:-(\d+|\+))?', time_str)
    if match:
        lower_limit = int(match.group(1))
        upper_limit = match.group(2)
        # If upper limit exists, choose upper limit; otherwise, choose lower limit
        return int(upper_limit) if upper_limit else lower_limit
    return None


df['Hours'] = df['D4'].apply(convert_to_hours)
d4_category_counts = df['Hours'].value_counts()
print(dict(d4_category_counts))
print("d4_category_counts:")
print(d4_category_counts)
# Out:
# {4.0: 242, 3.0: 181, 2.0: 105, 6.0: 17, 10.0: 16, 8.0: 15, 5.0: 13, 20.0: 11, 7.0: 9, 12.0: 6, 9.0: 5, 50.0: 4, 30.0: 2, 15.0: 1, 45.0: 1, 112.0: 1, 13.0: 1, 56.0: 1, 14.0: 1, 40.0: 1}
# d4_category_counts:
# Hours
# 4.0      242
# 3.0      181
# 2.0      105
# 6.0       17
# 10.0      16
# 8.0       15
# 5.0       13
# 20.0      11
# 7.0        9
# 12.0       6
# 9.0        5
# 50.0       4
# 30.0       2
# 15.0       1
# 45.0       1
# 112.0      1
# 13.0       1
# 56.0       1
# 14.0       1
# 40.0       1
# Name: count, dtype: int64

# %%
# check the D5:How often do you play Animal Crossing?
d5_category_counts = df['D5'].value_counts()
print(dict(d5_category_counts))
print("d5_category_counts:")
print(d5_category_counts)
# Out:
# {'1. Everyday': 362, '2. Almost everyday': 170, '3. Every week': 70, '4. Almost every week': 19, '6. Less than every month': 10, '5. Every month': 5, 'No': 1, 'Once in a while. Dont play as much anymore.': 1, 'More often than I exist in reality': 1, 'Not yet play': 1}
# d5_category_counts:
# D5
# 1. Everyday                                    362
# 2. Almost everyday                             170
# 3. Every week                                   70
# 4. Almost every week                            19
# 6. Less than every month                        10
# 5. Every month                                   5
# No                                               1
# Once in a while. Dont play as much anymore.      1
# More often than I exist in reality               1
# Not yet play                                     1
# Name: count, dtype: int64

# %%
# check the D6:What is your favorite activity in the game?
d6_category_counts = df['D6'].value_counts()
print(dict(d6_category_counts))
print("d6_category_counts:")
print(d6_category_counts)
# Out:
# {'Fishing': 150, 'Terraforming': 131, 'Planting trees/flowers': 128, 'Catching bugs': 74, 'Talking to villagers': 6, 'Decorating': 6, 'Interacting with villagers': 5, 'Decorating my island': 4, 'Designing': 3, 'Decorating ': 3, 'Interacting with my villagers': 2, 'Shopping': 2, 'Everything': 2, 'Trading': 2, 'decorating': 2, 'Design': 2, 'Design/interacting with villagers': 1, 'Designing the house': 1, 'Filling the museum': 1, 'trading, collection': 1, "Finishing my 'to do list' and going to the next day": 1, 'multiplayer ': 1, 'Befriending villagers': 1, 'Cataloging.making designs': 1, 'Collecting DIYs and stuff': 1, 'Have no specific favorite ': 1, 'Trading with other players ': 1, 'Decorating and buying clothes': 1, "Decorating my island (includes terraforming but that's only part of it!)": 1, 'Interacting with Villagers, Dressing Up': 1, ' creating little areas around my island like a pool area, market etc. ': 1, 'Talking to villagers!': 1, 'Designing my island with furniture ': 1, 'Gifting villagers ': 1, 'Mostly trading and designing': 1, 'Designing/repurposing areas of the island': 1, 'Drawing on the bulletin board and taking pictures.': 1, 'Interacting with friends': 1, 'Building new DIYs recipes and designing my island ': 1, 'Interacting with others': 1, 'Stalk market': 1, 'Decorating and nature landscaping': 1, 'Talking with villagers, visiting friends islands': 1, 'Exploiting natural resources and frivolously spending taxpayer money': 1, 'Looking for villagers': 1, 'Looking for surprising interaction and rares': 1, 'all of the above and visiting others islands too': 1, 'Chatting with villagers ': 1, 'Talking to residents': 1, 'All of the above, but also upgrading my house and getting new animals on my island.': 1, 'Online social interaction, visiting other peopleâ\x80\x99s Island': 1, 'Visiting with my neighbors': 1, 'Decorating/collecting decorations ': 1, 'Collecting and decorating': 1, 'Interacting with villagers ': 1, 'Time traveling': 1, 'talking to the villagers': 1, 'Decorating island': 1, 'Making custom designs ': 1, 'Not yet play': 1, 'having my sisters visit and creating hybrid flowers': 1, 'Helping other players': 1, 'All of the above': 1, 'Buying things, finding diys to decorate': 1, 'interacting with villagers ': 1, 'Decorating areas': 1, 'Everything ': 1, 'Shopping/cataloging': 1, 'Decorating and designing': 1, 'Decorating my house': 1, 'Collecting Fossils': 1, 'collecting items, visiting friends': 1, 'Playing with friends ': 1, 'Harassing the villagers': 1, 'Shopping and going to other islands': 1, 'designing recreational spaces': 1, 'Talking with villagers and contemplating the scenery': 1, 'Decorating/Designing my island': 1, 'Collecting things': 1, 'talking to my villagers': 1, 'Designing/decorating': 1, 'Collecting all items (bugs, fish, furniture and outfits), trading turnips': 1, 'Trading & talking to villagers': 1, 'buying items from Nooks Cranny and Able Sisters': 1, 'Stonks': 1, 'Turnips': 1, 'Collecting items': 1, 'Decorations ': 1, 'Villager hunting ': 1, 'Home decor': 1, 'Going to new islands, decorating ': 1, 'Talking to my villagers and checking what they are doing. ': 1, 'Decorating with furniture': 1, 'Talking to my villagers. ': 1, 'Talking to villagers and decorating ': 1, 'Making clothes ': 1, 'Watering other peopleâ\x80\x99s flowers for bells': 1, 'Taking to my villagers ': 1, 'Making designs': 1, 'Interacting with the island residents': 1, 'Completing daily tasks, improving my island and unlocking new item': 1, 'Planning out the layout of my island': 1, 'All.': 1, 'Decorating my home and outdoor spaces': 1, 'interacting with villagers': 1, 'interacting with villagers and friends': 1, 'Collecting and decorating ': 1, 'Varies on a day to day basis': 1, 'Interior Design': 1, 'Decorating/Coming up with new ideas': 1, 'Visiting friends islands ': 1, 'Complete the catalog': 1, 'Playing the game and hanging with friends': 1, 'Decorating my island and house with amenities': 1, 'Collecting ...
# d6_category_counts:
# D6
# Fishing                                        150
# Terraforming                                   131
# Planting trees/flowers                         128
# Catching bugs                                   74
# Talking to villagers                             6
#                                               ...
# Visiting other islands                           1
# Collecting furniture/designing houses            1
# Doing daily chores and talking to villagers      1
# Collecting furniture and D.I.Yâs               1
# Shopping and visiting friends' islands           1
# Name: count, Length: 134, dtype: int64

# %%
# Identify rows with invalid characters
df['Invalid Characters'] = df['D6'].apply(check_encoding)
print(df[df['Invalid Characters'] == False])
# Out:
#                    Date  nationality  Continent  Gender             education  \
# 45  2020-05-25 01:11:00  Philippines       Asia  Female           High school
# 220 2020-05-21 04:45:00          USA  US/Canada    Male  Undergraduate school
# 628 2020-05-25 00:31:00  Philippines       Asia  Female  Undergraduate school
#
#        Pet Age Ethnicity                Martial                 job  ... F25  \
# 45    Both  19     Asian  Single, never married           A student  ...   4
# 220   Both  24     White  Single, never married  Employed for wages  ...   5
# 628  A pet  42     Asian  Single, never married       Self-employed  ...   5
#
#     F26 F27  F28  F29  F30  F31  F32  Invalid Characters  Hours
# 45    4   5    5    1    5    4    3               False    4.0
# 220   1   5    4    2    5    3    1               False    6.0
# 628   4   4    5    2    4    3    2               False    8.0
#
# [3 rows x 97 columns]

# %%
print(df.at[45, "D6"])
print(df.at[220, "D6"])
print(df.at[628, "D6"])
print(df.at[521, "D7"])
# Out:
# Watering other peoples flowers for bells
# Collecting furniture and D.I.Y
# Online social interaction, visiting other peoples Island
# I’m doing fairly natural/Jurassic park themed

# %%
df.at[45, "D6"] = "Watering other peoples flowers for bells"
df.at[220, "D6"] = "Collecting furniture and D.I.Y"
df.at[628, "D6"] = "Online social interaction, visiting other peoples Island"

# %%
# check the D7:Which style/theme do you prefer when you can terraforming?
d7_category_counts = df['D7'].value_counts()
print(dict(d7_category_counts))
print("d7_category_counts:")
print(d7_category_counts)
# Out:
# {'Natural': 36, 'Neither': 13, 'none': 12, 'Natural ': 12, 'Snow Mountain': 7, 'jungle': 7, 'forest': 5, 'landscape': 5, 'Water': 5, 'fishing': 4, 'na': 4, 'swamp': 4, 'sandy beach': 4, 'Not sure': 3, 'Waterfalls': 3, 'okinteresting': 3, 'no': 3, 'seaside': 3, 'Cute': 3, 'Simple': 2, 'natural': 2, 'Mountain': 2, 'hill': 2, 'Animal crossing': 2, 'Planting trees/flowers': 2, 'riverside': 2, 'Park': 2, 'As natural as possible': 2, 'hilly area': 2, 'waterfalls': 2, 'Terraforming': 2, 'Farmer house theme': 2, 'Animation finishing': 2, 'NO': 2, 'Rustic': 2, 'Unsure': 2, 'N/a': 2, 'Japanese': 2, 'Japan style': 2, 'Japanese theme': 2, 'City ': 2, 'desert': 2, 'Terrain reconstruction': 2, 'Cottagecore': 2, 'I donâ\x80\x99t know ': 2, 'Discovering new species': 2, 'My own style': 2, 'Making waterfalls': 2, 'Forest': 2, 'Symmetrical ': 2, 'Relaxing': 1, "I like keeping it as natural and organic looking as possible, so I don't do a lot of terraforming.": 1, 'Cartoon': 1, 'pink': 1, 'Not sure ': 1, 'Recently i have tried experimenting by upgrading my right side of the island to tier 2, so basically the normal ground is in the 2nd floor and so i can create a kinda like basement area which looks cool from a higher standing point. ': 1, 'Mix type - wild world and city theme': 1, 'Outdoorsy': 1, 'Like a rich': 1, 'Dream castle': 1, 'Mix between modern and natural': 1, 'Cute, with lots of waterfalls': 1, 'shooting': 1, 'Catching bugs': 1, 'Enjoying scenery': 1, 'animal world': 1, 'I donâ\x80\x99t know what this is asking': 1, 'Pet': 1, 'Japanese old town': 1, 'Japan': 1, 'No preference:)': 1, 'Natural, like the GCN version': 1, 'Idk': 1, 'I still prefer natural design. Preserve rivers and trees.': 1, 'open country': 1, 'canyon': 1, 'my island is medieval themed': 1, 'realistic semi-urban': 1, 'Alpine, Western, Natural, Aged': 1, 'Depends on my mood': 1, 'Fantasy': 1, 'I donâ\x80\x99t understand this question. I use terraforming to create a larger, more open space': 1, "I'm not sure what this question is asking as it doesn't make sense. My island theme is pink/garden-like/structured": 1, 'None yet': 1, 'Magical woods': 1, 'Fandom, Cute': 1, 'Natural as possible while being functional': 1, 'Medieval': 1, 'Land with many waterfall around': 1, 'Rural life': 1, 'i donâ\x80\x99t understand this question. ': 1, 'Varied across the island': 1, 'random': 1, 'Wetland': 1, 'Beach ': 1, 'I just terraform for space issues. I like to preserve how my island initially looked as much as possible.': 1, 'Modern Theme': 1, 'Naturalistic Island with some brick walls & paths': 1, 'natural ': 1, 'various | multiple | diversiform | manif...': 1, 'I have not unlocked terraforming yet': 1, 'The jungle model': 1, 'fields on a hill': 1, 'Naturalistic does not too much terraforming': 1, 'Not terraforming yet': 1, 'Cottage/ Witchy / Magic': 1, 'french garden type': 1, 'Convenience': 1, 'Japaneses': 1, 'Country': 1, 'Water or cliff': 1, 'Imperial': 1, 'Japanese/anime town': 1, 'Cottagecore/Cute': 1, "I don't know what this means ": 1, 'Zen Garden': 1, 'Multiple themes to make the island look bigger and more diverse': 1, 'River terraforming': 1, 'Water building ': 1, ' through': 1, ' adventure': 1, 'Natural/outdoor look': 1, 'magic world': 1, 'I donâ\x80\x99t have a preference, if I like it, I keep it': 1, 'Personal preference. I like having waterfalls.': 1, 'Making rivers or ponds': 1, 'Cute / Natural / Fantasy': 1, 'A mix of Asian and European scenery': 1, 'Country style': 1, 'Unsure, I havenâ\x80\x99t reached that part of the game yet.': 1, 'Pathways': 1, 'Finding villagers': 1, 'I donâ\x80\x99t have a set style, I just kind of do stuff and see what happens. ': 1, ' wilderness': 1, 'Luxury + avatar theme': 1, 'Earthly': 1, 'Cottagecore aesthetic': 1, 'I love creating something inspired of real life destinations/tourist spots': 1, 'Forest/Rustic': 1, 'naturally': 1, 'garden': 1, "I'm not sure what this question is asking": 1, 'Zoo': 1, 'My world is similar': 1, 'After k.k. s ...
# d7_category_counts:
# D7
# Natural                                                                                                                36
# Neither                                                                                                                13
# none                                                                                                                   12
# Natural                                                                                                                12
# Snow Mountain                                                                                                           7
#                                                                                                                        ..
# Simplistic/natural                                                                                                      1
# I like to keep my island looking kind of "natural" with houses and other features spread out. lots of custom paths.     1
# Lowkey (not much terraforming)                                                                                          1
# I only use terraforming to enhance or slightly change the original island layout                                        1
# Countryside/Japanese theme                                                                                              1
# Name: count, Length: 492, dtype: int64

# %%
# Identify rows with invalid characters
df['Invalid Characters'] = df['D7'].apply(check_encoding)
def changeEncode(text):
    return text.encode('iso-8859-1', errors='replace').decode('utf-8', errors='ignore')

df.loc[df['Invalid Characters'] == False, 'D7'] = df[df['Invalid Characters'] == False]['D7'].apply(changeEncode)

df[df['Invalid Characters'] == False]["D7"]

df = df.drop(columns="Invalid Characters")

# %%
# check the values columns
df.describe()
# Out:
#                              Date          C1          C2          C3  \
# count                         640  640.000000  640.000000  640.000000
# mean   2020-05-24 06:01:31.500000    3.784375    2.987500    4.100000
# min           2020-05-15 14:20:00    1.000000    1.000000    1.000000
# 25%           2020-05-21 06:16:45    3.000000    2.000000    4.000000
# 50%           2020-05-25 04:14:00    4.000000    3.000000    4.000000
# 75%           2020-05-25 15:00:00    4.000000    4.000000    5.000000
# max           2020-06-15 18:51:00    5.000000    5.000000    5.000000
# std                           NaN    0.941350    1.076059    0.869947
#
#                C4          C5          C6          C7          C8          C9  \
# count  640.000000  640.000000  640.000000  640.000000  640.000000  640.000000
# mean     2.700000    4.334375    2.154688    4.309375    3.253125    4.284375
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      2.000000    4.000000    1.000000    4.000000    2.000000    4.000000
# 50%      3.000000    5.000000    2.000000    5.000000    3.000000    4.000000
# 75%      3.000000    5.000000    3.000000    5.000000    4.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
# std      1.049927    0.858032    1.059783    0.881690    1.303056    0.837542
#
#        ...         F24         F25         F26         F27         F28  \
# count  ...  640.000000  640.000000  640.000000  640.000000  640.000000
# mean   ...    1.825000    3.728125    3.298437    4.087500    3.987500
# min    ...    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%    ...    1.000000    3.000000    3.000000    3.000000    3.000000
# 50%    ...    1.000000    4.000000    3.000000    4.000000    4.000000
# 75%    ...    2.000000    5.000000    4.000000    5.000000    5.000000
# max    ...    5.000000    5.000000    5.000000    5.000000    5.000000
# std    ...    1.141341    1.181955    1.164148    0.953619    0.988114
#
#               F29         F30         F31         F32       Hours
# count  640.000000  640.000000  640.000000  640.000000  633.000000
# mean     2.035938    3.909375    3.100000    2.178125    4.933649
# min      1.000000    1.000000    1.000000    1.000000    2.000000
# 25%      1.000000    3.000000    2.000000    1.000000    3.000000
# 50%      2.000000    4.000000    3.000000    2.000000    4.000000
# 75%      3.000000    5.000000    4.000000    3.000000    4.000000
# max      5.000000    5.000000    5.000000    5.000000  112.000000
# std      1.120427    1.063510    1.359831    1.270647    7.095106
#
# [8 rows x 77 columns]

# %%
profile = ProfileReport(df, title="Profiling Report")
profile.to_widgets()
profile.to_file("animal_cross.html")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 96 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         640 non-null    datetime64[ns]
#  1   nationality  640 non-null    object
#  2   Continent    640 non-null    object
#  3   Gender       640 non-null    object
#  4   education    640 non-null    object
#  5   Pet          640 non-null    object
#  6   Age          640 non-null    object
#  7   Ethnicity    640 non-null    object
#  8   Martial      640 non-null    object
#  9   job          640 non-null    object
#  10  isolated     640 non-null    object
#  11  Time         640 non-null    object
#  12  Covid-19     640 non-null    object
#  13  C1           640 non-null    int64
#  14  C2           640 non-null    int64
#  15  C3           640 non-null    int64
#  16  C4           640 non-null    int64
#  17  C5           640 non-null    int64
#  18  C6           640 non-null    int64
#  19  C7           640 non-null    int64
#  20  C8           640 non-null    int64
#  21  C9           640 non-null    int64
#  22  C10          640 non-null    int64
#  23  C11          640 non-null    int64
#  24  C12          640 non-null    int64
#  25  C13          640 non-null    int64
#  26  C14          640 non-null    int64
#  27  C15          640 non-null    int64
#  28  D1           640 non-null    object
#  29  D2           640 non-null    object
#  30  D3           640 non-null    object
#  31  D4           640 non-null    object
#  32  D5           640 non-null    object
#  33  D6           640 non-null    object
#  34  D7           640 non-null    object
#  35  E1           640 non-null    int64
#  36  E2           640 non-null    int64
#  37  E3           640 non-null    int64
#  38  E4           640 non-null    int64
#  39  E5           640 non-null    int64
#  40  E6           640 non-null    int64
#  41  E7           640 non-null    int64
#  42  E8           640 non-null    int64
#  43  E9           640 non-null    int64
#  44  E10          640 non-null    int64
#  45  E11          640 non-null    int64
#  46  E12          640 non-null    int64
#  47  E13          640 non-null    int64
#  48  E14          640 non-null    int64
#  49  E15          640 non-null    int64
#  50  E16          640 non-null    int64
#  51  E17          640 non-null    int64
#  52  E18          640 non-null    int64
#  53  E19          640 non-null    int64
#  54  E20          640 non-null    int64
#  55  E21          640 non-null    int64
#  56  E22          640 non-null    int64
#  57  E23          640 non-null    int64
#  58  E24          640 non-null    int64
#  59  E25          640 non-null    int64
#  60  E26          640 non-null    int64
#  61  E27          640 non-null    int64
#  62  E28          640 non-null    int64
#  63  F1           640 non-null    int64
#  64  F2           640 non-null    int64
#  65  F3           640 non-null    int64
#  66  F4           640 non-null    int64
#  67  F5           640 non-null    int64
#  68  F6           640 non-null    int64
#  69  F7           640 non-null    int64
#  70  F8           640 non-null    int64
#  71  F9           640 non-null    int64
#  72  F10          640 non-null    int64
#  73  F11          640 non-null    int64
#  74  F12          640 non-null    int64
#  75  F13          640 non-null    int64
#  76  F14          640 non-null    int64
#  77  F15          640 non-null    int64
#  78  F16          640 non-null    int64
#  79  F17          640 non-null    int64
#  80  F18          640 non-null    int64
#  81  F19          640 non-null    int64
#  82  F20          640 non-null    int64
#  83  F21          640 non-null    int64
#  84  F22          640 non-null    int64
#  85  F23          640 non-null    int64
#  86  F24          640 non-null    int64
#  87  F25          640 non-null    int64
#  88  F26          640 non-null    int64
#  89  F27          640 non-null    int64
#  90  F28          640 non-null    int64
#  91  F29          640 non-null    int64
#  92  F30          640 non-null    int64
#  93  F31          640 non-null    int64
#  94  F32          640 non-null    int64
#  95  Hours        633 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(75), object(19)
# memory usage: 480.1+ KB

# %%
df.to_csv('coursework_cleaned.csv')
